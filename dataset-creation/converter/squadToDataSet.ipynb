# %%
import pandas as pd

# %%
import json
import numpy as np

# based on: https://www.kaggle.com/code/sanjay11100/squad-stanford-q-a-json-to-pandas-dataframe
def squad_json_to_dataframe(file_path, record_path=['data','paragraphs','qas','answers']):
    """
    input_file_path: path to the squad json file.
    record_path: path to deepest level in json file default value is
    ['data','paragraphs','qas','answers']
    """
    file = json.loads(open(file_path).read())
#     print(file)
    # parsing different level's in the json file
    js = pd.json_normalize(file, record_path)
    m = pd.json_normalize(file, record_path[:-1])
    r = pd.json_normalize(file,record_path[:-2])
    # combining it into single dataframe
    idx = np.repeat(r['context'].values, r.qas.str.len())
    m['context'] = idx
    data = m[['id','question','context','answers']].set_index('id').reset_index()
    data['c_id'] = data['context'].factorize()[0]
    return data

# %%
data = squad_json_to_dataframe('kolZhutSQuAD.json')

# %%
data
# Out:
#                                       id  \
# 0   bccc3d0f-1d0a-4a4f-b1a8-54095af42e2c
# 1   f05c4a2a-f458-4d2b-a452-f2f252097d76
# 2   636260b7-6680-4d9e-bf88-4ae98aaa01f7
# 3   0cdbeb40-b52c-41dc-af0c-ffdf78b40f10
# 4   6a6f9a7e-31f7-4a1c-b8c5-fea6eb5de8db
# 5   e9832189-e967-4c0b-9094-f9d1ef42042f
# 6   dd684837-96b6-453e-b4a1-e24018d26577
# 7   10bf7046-78fd-448b-b7cb-c460f6ede2ae
# 8   be682168-0bda-47bc-99f6-092a17a2abc1
# 9   cd3da272-a641-40e5-b7bc-4dec55f4c876
# 10  81582363-beea-427b-a7ae-465cf0cb025c
# 11  79c8902d-cc7f-4101-9d35-1d32a70f7afd
# 12  9c2c1e84-7071-4ac0-aa06-4768a686972f
# 13  b1abd15f-e6d8-4012-8cd2-9cab4751bb46
# 14  2df8ee79-c693-4df1-9dd5-13a190153f56
# 15  5eae8f2a-860d-4888-9624-b5559b4df2c1
# 16  047e30df-213b-48c4-9f02-c6602d399352
# 17  ef8c1fa6-b3e7-4c50-9bda-95e4bb8251e2
# 18  e95ea72c-bb63-4785-b65a-873979bc115d
# 19  eb1c2ab3-a71b-4e3e-987f-2afe6e0bfd31
# 20  e99bdbd8-0668-4ed3-b21e-76ed0009ba14
#
#                                        question  \
# 0                מתי מסתיימים יחסי העובד-מעסיק?
# 1                  מה המעסיק חייב להעניק לעובד?
# 2               האם העובד עדיין זכאי לרכב צמוד?
# 3                מהו בסיס השכר לחישוב הפיצויים?
# 4                         מה העובד מפסיק לצבור?
# 5                       האם העובד זכאי להפרשות?
# 6                               ממה העובד פטור?
# 7                               מהו גובה הפטור?
# 8                             כיצד תחויב היתרה?
# 9         אחרי הפרת משמעת מה ניתן לשלול מהעובד?
# 10               כיצד נספרים ימי ההודעה המוקדמת
# 11    האם ימי ההודעה המוקדמת כולל רק ימי עבדוה?
# 12           מהו הפיצוי לעובד המוותר על העסקתו?
# 13               מהו יום המנוחה השבועי ליהודים?
# 14                ממתי מתחיל יום המנוחה השבועי?
# 15                 מתי מסתיים יום המנוחה השבועי
# 16             מהו יום המנוחה לעובד שאינו יהודי
# 17                       מהו הגמול ביום המנוחה?
# 18                     מהו אורך המנוחה השבועית?
# 19            מהו הגמול ביום המנוחה לעובד שעתי?
# 20  מהו הגמול ביום המנוחה לעובד במשכורת חודשית?
#
#                                               context  \
# 0   יחסי העובד-מעסיק בין הצדדים מסתיימים עם תום תק...
# 1   יחסי העובד-מעסיק בין הצדדים מסתיימים עם תום תק...
# 2   המעסיק רשאי לוותר על עבודתו של העובד בתקופת הה...
# 3   המעסיק רשאי לוותר על עבודתו של העובד בתקופת הה...
# 4   המעסיק רשאי לוותר על עבודתו של העובד בתקופת הה...
# 5   המעסיק רשאי לוותר על עבודתו של העובד בתקופת הה...
# 6   תשלום שקיבל העובד כ"חלף הודעה מוקדמת" פטור ממס...
# 7   תשלום שקיבל העובד כ"חלף הודעה מוקדמת" פטור ממס...
# 8   תשלום שקיבל העובד כ"חלף הודעה מוקדמת" פטור ממס...
# 9   אם העובד פוטר בנסיבות שבהם הוא אינו זכאי לפיצו...
# 10  ספירת ימי ההודעה המוקדמת היא לפי ימים קלנדריים...
# 11  ספירת ימי ההודעה המוקדמת היא לפי ימים קלנדריים...
# 12  ספירת ימי ההודעה המוקדמת היא לפי ימים קלנדריים...
# 13  לעובד יהודי המנוחה השבועית תכלול את יום השבת. ...
# 14  לעובד יהודי המנוחה השבועית תכלול את יום השבת. ...
# 15  לעובד יהודי המנוחה השבועית תכלול את יום השבת. ...
# 16  לעובד יהודי המנוחה השבועית תכלול את יום השבת. ...
# 17  לעובד יהודי המנוחה השבועית תכלול את יום השבת. ...
# 18  לעובד יהודי המנוחה השבועית תכלול את יום השבת. ...
# 19  עובדים במשכורת חודשית זכאים לתוספת של 50% מערך...
# 20  עובדים במשכורת חודשית זכאים לתוספת של 50% מערך...
#
#                                               answers  c_id
# 0   [{'answer_start': 36, 'text': ' עם תום תקופת ה...     0
# 1   [{'answer_start': 154, 'text': 'המעסיק חייב לה...     0
# 2   [{'answer_start': 855, 'text': 'עובד אינו זכאי...     1
# 3   [{'answer_start': 201, 'text': '"השכר הרגיל" ש...     1
# 4   [{'answer_start': 633, 'text': 'זכויות סוציאלי...     1
# 5   [{'answer_start': 656, 'text': 'אינו זכאי להפר...     1
# 6          [{'answer_start': 44, 'text': 'מס הכנסה'}]     2
# 7    [{'answer_start': 328, 'text': 'עד גובה התקרה'}]     2
# 8   [{'answer_start': 369, 'text': 'לפי מדרגות המס...     2
# 9   [{'answer_start': 87, 'text': 'תקופת ההודעה המ...     3
# 10  [{'answer_start': 29, 'text': 'לפי ימים קלנדרי...     4
# 11  [{'answer_start': 63, 'text': 'כוללת גם את ימי...     4
# 12  [{'answer_start': 280, 'text': 'גובה השכר בלבד...     4
# 13             [{'answer_start': 40, 'text': 'השבת'}]     5
# 14  [{'answer_start': 104, 'text': 'מכניסת השבת בי...     5
# 15       [{'answer_start': 130, 'text': 'מוצאי שבת'}]     5
# 16  [{'answer_start': 211, 'text': 'יום שישי, או ש...     5
# 17  [{'answer_start': 625, 'text': '150% לפחות עבו...     5
# 18         [{'answer_start': 370, 'text': '36 שעות'}]     5
# 19  [{'answer_start': 210, 'text': 'שכר של 150% מש...     6
# 20  [{'answer_start': 28, 'text': 'לתוספת של 50% מ...     6
